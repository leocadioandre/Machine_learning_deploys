# %%
import pandas as pd

# %%
df = pd.read_csv('car_information_clean.csv',sep = ',')
df.head()
# Out:
#                                           Unnamed: 0  \
# 0  0,https://pr.olx.com.br/regiao-de-londrina/aut...
# 1  1,https://pr.olx.com.br/regiao-de-londrina/aut...
# 2  2,https://pr.olx.com.br/regiao-de-londrina/aut...
# 3  3,https://pr.olx.com.br/regiao-de-londrina/aut...
# 4                                                  4
#
#                                                 link        brand    price  \
# 0                                                NaN          NaN      NaN
# 1                                                NaN          NaN      NaN
# 2                                                NaN          NaN      NaN
# 3                                                NaN          NaN      NaN
# 4  https://pr.olx.com.br/regiao-de-londrina/autos...  gmchevrolet  16500.0
#
#    cartype  model gearbox  regdate   mileage motorpower  fuel car_steering  \
# 0      NaN    NaN     NaN      NaN       NaN        NaN   NaN          NaN
# ...

# %%
df1 = pd.read_csv("car_information_clean_.csv")

# %%
df2 = pd.read_csv("car_information_raw.csv")

# %%
df1.head(50)
# Out:
#     Unnamed: 0                                               link  \
# 0            0  https://pr.olx.com.br/regiao-de-londrina/autos...
# 1            1  https://pr.olx.com.br/regiao-de-londrina/autos...
# 2            2  https://pr.olx.com.br/regiao-de-londrina/autos...
# 3            3  https://pr.olx.com.br/regiao-de-londrina/autos...
# 4            4  https://pr.olx.com.br/regiao-de-londrina/autos...
# 5            5  https://pr.olx.com.br/regiao-de-londrina/autos...
# 6            6  https://pr.olx.com.br/regiao-de-londrina/autos...
# 7            7  https://pr.olx.com.br/regiao-de-londrina/autos...
# 8            8  https://pr.olx.com.br/regiao-de-londrina/autos...
# 9            9  https://pr.olx.com.br/regiao-de-londrina/autos...
# 10          10  https://pr.olx.com.br/regiao-de-londrina/autos...
# 11          11  https://pr.olx.com.br/regiao-de-londrina/autos...
# 12          12  https://pr.olx.com.br/regiao-de-londrina/autos...
# ...

# %%
df3 = pd.concat(map(pd.read_csv, ['car_information_raw.csv', 'car_information_clean_.csv']))

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11593 entries, 0 to 11592
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    11593 non-null  int64
#  1   link          11593 non-null  object
#  2   brand         11593 non-null  object
#  3   price         11593 non-null  int64
#  4   cartype       11593 non-null  object
#  5   model         11593 non-null  object
#  6   gearbox       11593 non-null  object
#  7   regdate       11593 non-null  int64
#  8   mileage       11593 non-null  int64
#  9   motorpower    11593 non-null  object
#  10  fuel          11593 non-null  object
#  11  car_steering  11593 non-null  object
#  12  carcolor      11593 non-null  object
#  13  exchange      11593 non-null  object
#  14  version       11593 non-null  object
#  15  doors         11593 non-null  object
#  16  financial     11593 non-null  object
#  17  extra         11593 non-null  object
# ...

# %%
df1.Y.value_counts()
# Out:
# 0    9392
# 1    2201
# Name: Y, dtype: int64

# %%
df2.Y.value_counts()
# Out:
# 0.0    3893
# 1.0     661
# Name: Y, dtype: int64

# %%
661/3893
# Out:
# 0.1697919342409453

# %%
2201/9392
# Out:
# 0.23434838160136287

# %%
1700/9893
# Out:
# 0.17183867380976448
